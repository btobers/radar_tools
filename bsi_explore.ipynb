# %%
# open and inspect bsi radar data

# %%
import h5py
import numpy as np
import os
import xml.etree.ElementTree as ET
from datetime import datetime, timedelta
import sys, glob, os, argparse, re

# %%
# Define a custom sorting function
def sort_by_numeric_value(s):
    return int(s.split('_')[1])  # Split the string by '_' and return the second part as an integer


def _xmlGetVal(xml, name):
    """
    Borrowed from dlilien's impDAR: Look up a value in an XML fragment. Mod from Nat Wilson's irlib.
    """
    m = re.search(r'<Name>{0}</Name>[\r]?\n<Val>'.format(
        name.replace(' ', r'\s')), xml, flags=re.IGNORECASE)
    if m is not None:
        tail = xml[m.span()[1]:]
        end = tail.find('</Val')
        return tail[:end]
    else:
        return None

def dm2dd(dms):
    return int(dms/100) + (dms - 100*int(dms/100))/60

# %%
fpath = '/Users/btober/Desktop/tmp//kennicott2_20240527.hdf5'
print(os.path.isfile(fpath))
# Out:
# True

# %%
with h5py.File(fpath, "r")  as fd:
    datestr = fpath.split('/')[-1].split('_')[-1].split('.')[0]
    date_obj = datetime.strptime(datestr, "%Y%m%d") 
    # loop through lines
    print(fd.keys())
    line = 'line_0'
    # for line in fd.keys():
        # loop through traces
        # i=0
    traces = sorted(fd[line].keys(), key=sort_by_numeric_value)
    print(traces)
    trace = traces[-1]
    gps_xml = fd[line][trace]["datacapture_0/echogram_0"].attrs['GPSData_xml']
    print(list(fd[line][trace]["datacapture_0/echogram_0"].attrs))
    print(float(_xmlGetVal(gps_xml, 'Lat')))
    print(float(_xmlGetVal(gps_xml, 'Long')))
    print(dm2dd(float(_xmlGetVal(gps_xml, 'Lat'))))
    print(dm2dd(float(_xmlGetVal(gps_xml, 'Long'))))
    print(fd[line][trace]["datacapture_0/echogram_0"].attrs["DigitizerMetaData_xml"])
        # for trace in fd[line].keys():
        #     if i==0:
        # print(list(fd[line][trace]['datacapture_0']['echogram_0'].attrs))
        # print()
        # print(fd[line][trace]['datacapture_0']['echogram_0'].attrs['AGLData_xml'])
        # print()
        # print(fd[line][trace]['datacapture_0']['echogram_0'].attrs['DigitizerMetaData_xml'])
        # print()
        # print(fd[line][trace]['datacapture_0']['echogram_0'].attrs['GPSData_xml'])
        # print()
        # print(fd[line][trace]['datacapture_0']['echogram_0'].attrs['GPS_UTMData_xml'])
        # print()
        # print(fd[line][trace]['datacapture_0']['echogram_0'].attrs['PCSaveTimestamp'])
        #     i+=1
    # print(fd.keys())
# Out:
# <KeysViewHDF5 ['line_0']>
# ['AGLData_xml', 'DigitizerMetaData_xml', 'GPSData_xml', 'GPS_UTMData_xml', 'PCSaveTimestamp']
# 6126.37762
# -14253.78312
# 61.439627
# -142.89638533333334
# <Cluster>
# <Name>DigitizerMetaData</Name>
# <NumElts>3</NumElts>
# <Cluster>
# <Name>DigitizerSettings</Name>
# <NumElts>5</NumElts>
# <Cluster>
# <Name>Vertical</Name>
# <NumElts>3</NumElts>
# <DBL>
# <Name>VoltageRange</Name>
# <Val>5.00000000000000E-2</Val>
# </DBL>
# <DBL>
# <Name>VoltageOffset</Name>
# <Val>0.00000000000000</Val>
# </DBL>
# <I32>
# <Name>VerticalCoupling</Name>
# <Val>1</Val>
# </I32>
# </Cluster>
# <Cluster>
# <Name>Channel</Name>
# <NumElts>1</NumElts>
# <DBL>
# <Name>MaxInputFrequency</Name>
# <Val>200000000.00000000000000</Val>
# </DBL>
# </Cluster>
# <Cluster>
# <Name>Horizontal</Name>
# <NumElts>2</NumElts>
# <DBL>
# <Name>SampleRate</Name>
# <Val>125000000.00000000000000</Val>
# </DBL>
# <I32>
# <Name>RecordLength</Name>
# <Val>1500</Val>
# </I32>
# </Cluster>
# <Cluster>
# <Name>Trigger</Name>
# <NumElts>12</NumElts>
# <U16>
# <Name>TriggerType</Name>
# <Val>0</Val>
# </U16>
# <DBL>
# <Name>TriggerDelay</Name>
# <Val>0.00000000000000</Val>
# </DBL>
# <DBL>
# <Name>ReferencePosition</Name>
# <Val>5.00000000000000</Val>
# </DBL>
# <DBL>
# <Name>TriggerLevel</Name>
# <Val>4.80000000000000E-2</Val>
# </DBL>
# <DBL>
# <Name>Hysteresis</Name>
# <Val>0.00000000000000</Val>
# </DBL>
# <DBL>
# <Name>LowLevel</Name>
# <Val>0.00000000000000</Val>
# </DBL>
# <DBL>
# <Name>HighLevel</Name>
# <Val>0.00000000000000</Val>
# </DBL>
# <U16>
# <Name>TriggerCoupling</Name>
# <Val>1</Val>
# </U16>
# <I32>
# <Name>TriggerWindowMode</Name>
# <Val>0</Val>
# </I32>
# <I32>
# <Name>TriggerSlope</Name>
# <Val>0</Val>
# </I32>
# <String>
# <Name>TriggerSource</Name>
# <Val>Radar (ch 0)</Val>
# </String>
# <I32>
# <Name>TriggerModifier</Name>
# <Val>2</Val>
# </I32>
# </Cluster>
# <String>
# <Name>ChannelName</Name>
# <Val>0</Val>
# </String>
# </Cluster>
# <U16>
# <Name>Stacking</Name>
# <Val>128</Val>
# </U16>
# <Cluster>
# <Name>RadargramExtraInfo</Name>
# <NumElts>2</NumElts>
# <DBL>
# <Name>RelativeInitialX</Name>
# <Val>-6.00000021222513E-7</Val>
# </DBL>
# <DBL>
# <Name>XIncrement</Name>
# <Val>7.99999977374455E-9</Val>
# </DBL>
# </Cluster>
# </Cluster>
